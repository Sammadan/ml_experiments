# %%
import tensorflow as tf
import cv2
import glob
import skimage.io as io
import matplotlib.pyplot as plt
import os
import pandas as pd
import numpy as np
import re

# %%
from jupyterthemes import get_themes
import jupyterthemes as jt
from jupyterthemes.stylefx import set_nb_theme

# %%
set_nb_theme('onedork')
set_nb_theme('chesterish')
#set_nb_theme('grade3')
#set_nb_theme('oceans16')
set_nb_theme('solarizedl')
#set_nb_theme('solarizedd')
set_nb_theme('monokai')
# Out:
# <style> div#notebook {
#  font-family: sans-serif;
#  font-size: 13pt;
#  line-height: 170%;
#  color: #f8f8f0;
#  -webkit-font-smoothing: antialiased !important;
# }
# body,
# div.body {
#  font-family: sans-serif;
#  font-size: 13pt;
#  color: #f8f8f0;
#  background-color: #1e1e1e;
#  background: #1e1e1e;
#  -webkit-font-smoothing: antialiased !important;
# }
# body.notebook_app {
#  padding: 0;
#  background-color: #1e1e1e;
#  background: #1e1e1e;
#  padding-right: 0px !important;
#  overflow-y: hidden;
# }
# a {
#  font-family: sans-serif;
#  color: #f8f8f0;
#  -webkit-font-smoothing: antialiased !important;
# }
# a:hover,
# a:focus {
#  color: #f8f8f0;
#  -webkit-font-smoothing: antialiased !important;
# }
# .list_header,
# div#notebook_list_header.row.list_header {
#  font-size: 14pt;
#  color: #f8f8f0;
#  background-color: transparent;
#  height: 35px;
# }
# i.fa.fa-folder {
#  display: inline-block;
#  font: normal normal normal 14px "FontAwesome";
# ...

# %%
with open("labels/1.txt") as f:
    img=f.read()
    print(img)
# Out:
# 0 288	148	938	685

# %%
import csv

# %%
img=cv2.imread("/home/dexter/datasets/drones/drone_photos/1.jpg")

# %%
cv2.imshow("img",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img.shape
# Out:
# (721, 1200, 3)

# %%
print(0.4750346740638003*721)
# Out:
# 342.5

# %%
csv_table=pd.read_table("/home/dexter/Desktop/dronesurv/drone-detection/DataSets/Drones/positive/1.bboxes.tsv",sep='\t')

# %%
csv_table.loc[:]
# Out:
# Empty DataFrame
# Columns: [288, 148, 938, 685]
# Index: []

# %%
csv_table="0,"+str(csv_table)

# %%
print(csv_table)
# Out:
# 0,[]

# %%
dir=os.listdir("/home/dexter/Desktop/dronesurv/drone-detection/DataSets/Drones/positive")

# %%
i=0
for file in dir:
    if file[-3:]=="tsv":
        
        print(file)
        i+=1

        tsv_file=file
        csv_table=pd.read_table("/home/dexter/Desktop/dronesurv/drone-detection/DataSets/Drones/positive/"+file,sep='\t')
        file=re.sub(".bboxes.tsv",".tsv",file)
        csv_table.to_csv("lab/"+file[:-3]+"csv",index=False)
        
print(i)
# Out:
# 194.bboxes.tsv
# 13.bboxes.tsv
# 119.bboxes.tsv
# 275.bboxes.tsv
# 136.bboxes.tsv
# 83.bboxes.tsv
# 108.bboxes.tsv
# 350.bboxes.tsv
# 78.bboxes.tsv
# 261.bboxes.tsv
# 204.bboxes.tsv
# 152.bboxes.tsv
# 335.bboxes.tsv
# 253.bboxes.tsv
# 42.bboxes.tsv
# 143.bboxes.tsv
# 196.bboxes.tsv
# 250.bboxes.tsv
# 281.bboxes.tsv
# 268.bboxes.tsv
# 205.bboxes.tsv
# 145.bboxes.tsv
# 8.bboxes.tsv
# 64.bboxes.tsv
# 20.bboxes.tsv
# 206.bboxes.tsv
# 220.bboxes.tsv
# 273.bboxes.tsv
# 41.bboxes.tsv
# 207.bboxes.tsv
# 290.bboxes.tsv
# 293.bboxes.tsv
# 328.bboxes.tsv
# 87.bboxes.tsv
# 21.bboxes.tsv
# 188.bboxes.tsv
# 32.bboxes.tsv
# 232.bboxes.tsv
# 343.bboxes.tsv
# 49.bboxes.tsv
# 151.bboxes.tsv
# 101.bboxes.tsv
# 28.bboxes.tsv
# 327.bboxes.tsv
# 168.bboxes.tsv
# 178.bboxes.tsv
# 96.bboxes.tsv
# 200.bboxes.tsv
# 125.bboxes.tsv
# 202.bboxes.tsv
# 74.bboxes.tsv
# 102.bboxes.tsv
# 224.bboxes.tsv
# 79.bboxes.tsv
# 292.bboxes.tsv
# 164.bboxes.tsv
# 222.bboxes.tsv
# 242.bboxes.tsv
# 36.bboxes.tsv
# ...

# %%
dir2=os.listdir("lab/")

# %%
for file in dir2:
    with open("lab/"+file) as infile,open("finaltry.csv","a+") as outfile:
        data=str(infile.read())
        if data[0]=='0':
            print(file)
            print(data)
            outfile.write(file+","+data)
# Out:
# 186.csv
# 0,301,119,922,532
#
# 340.csv
# 0,924,257,1169,405
#
# 202.csv
# 0,743,336,1221,607
#
# 168.csv
# 0,952,636,1219,768
#
# 129.csv
# 0,136,161,357,273
# 718,238,943,357
#
# 10.csv
# 0,1267,482,1432,593
#
# 283.csv
# 0,1219,486,1365,586
#
# 258.csv
# 0,1114,259,1187,309
#
# 349.csv
# 0,904,651,1190,791
#
# 145.csv
# 0,611,392,918,563
#
# 293.csv
# 0,293,394,434,468
#
# 218.csv
# 0,611,138,693,188
#
# 312.csv
# 0,1167,296,1348,436
#
# 244.csv
# 0,1127,474,1254,599
#
# 141.csv
# 0,396,460,739,648
#
# 114.csv
# 0,547,386,1079,653
#
# 229.csv
# 0,881,23,1294,200
#
# 104.csv
# 0,2051,780,2473,941
#
# 148.csv
# 0,564,95,1003,392
#
# 319.csv
# 0,293,119,394,186
#
# 136.csv
# 0,472,2,1920,781
#
# 1.csv
# 0,288,148,938,685
#
# 160.csv
# 0,1177,559,1329,659
#
# 121.csv
# 0,79,28,208,81
#
# 336.csv
# 0,555,108,1590,739
#
# 53.csv
# 0,637,486,882,622
#
# 162.csv
# 0,188,486,1734,1087
#
# 2.csv
# 0,561,144,693,252
#
# 123.csv
# 0,820,482,918,563
#
# 234.csv
# 0,1183,820,1329,914
#
# ...

# %%
for file in dir2:
    with open("lab/"+file) as infile,open("lab2/"+file,"a+") as outfile:
        data=str(infile.read())
        data="1"+data[1:]
        outfile.write(data)

# %%
data[1:]
# Out:
# ',670,303,1046,541\n'
